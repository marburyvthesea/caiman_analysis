# %%
#!/usr/bin/env python

try:
    get_ipython().magic(u'load_ext autoreload')
    get_ipython().magic(u'autoreload 2')
    get_ipython().magic(u'matplotlib qt')
except:
    pass

import logging
import matplotlib.pyplot as plt
import numpy as np

logging.basicConfig(format=
                          "%(relativeCreated)12d [%(filename)s:%(funcName)20s():%(lineno)s] [%(process)d] %(message)s",
                    # filename="/tmp/caiman.log",
                    level=logging.DEBUG)

import caiman as cm
from caiman.source_extraction import cnmf
from caiman.utils.utils import download_demo
from caiman.utils.visualization import inspect_correlation_pnr
from caiman.motion_correction import MotionCorrect
from caiman.source_extraction.cnmf import params as params
from caiman.utils.visualization import plot_contours, nb_view_patches, nb_plot_contour
import cv2

try:
    cv2.setNumThreads(0)
except:
    pass
import bokeh.plotting as bpl
bpl.output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
fnames = ['/Volumes/My_Passport/MiniscopeMovies/caiman_pipeline_test/H10_M19_S59msCam9_substack.tif']  # filename to be processed

# %%
#%% start a cluster for parallel processing (if a cluster already exists it will be closed and a new session will be opened)
if 'dview' in locals():
    cm.stop_server(dview=dview)
c, dview, n_processes = cm.cluster.setup_cluster(
    backend='local', n_processes=None, single_thread=False)

# %%
# dataset dependent parameters
frate = 20                       # movie frame rate
decay_time = 0.4                 # length of a typical transient in seconds

# motion correction parameters
motion_correct = True    # flag for performing motion correction
pw_rigid = False         # flag for performing piecewise-rigid motion correction (otherwise just rigid)
gSig_filt = (3, 3)       # size of high pass spatial filtering, used in 1p data
max_shifts = (5, 5)      # maximum allowed rigid shift
strides = (48, 48)       # start a new patch for pw-rigid motion correction every x pixels
overlaps = (24, 24)      # overlap between pathes (size of patch strides+overlaps)
max_deviation_rigid = 3  # maximum deviation allowed for patch with respect to rigid shifts
border_nan = 'copy'      # replicate values along the boundaries

mc_dict = {
    'fnames': fnames,
    'fr': frate,
    'decay_time': decay_time,
    'pw_rigid': pw_rigid,
    'max_shifts': max_shifts,
    'gSig_filt': gSig_filt,
    'strides': strides,
    'overlaps': overlaps,
    'max_deviation_rigid': max_deviation_rigid,
    'border_nan': border_nan
}

opts = params.CNMFParams(params_dict=mc_dict)
# Out:
#       223973 [params.py:                 set():780] [1204] Changing key fnames in group data from None to ['/Volumes/My_Passport/MiniscopeMovies/caiman_pipeline_test/H10_M19_S59msCam9_substack.tif']
#       223975 [params.py:                 set():780] [1204] Changing key fr in group data from 30 to 20
#       223976 [params.py:                 set():780] [1204] Changing key max_shifts in group motion from (6, 6) to (5, 5)
#       223977 [params.py:                 set():780] [1204] Changing key gSig_filt in group motion from None to (3, 3)
#       223980 [params.py:                 set():780] [1204] Changing key strides in group motion from (96, 96) to (48, 48)
#       223981 [params.py:                 set():780] [1204] Changing key overlaps in group motion from (32, 32) to (24, 24)

# %%
if motion_correct:
    # do motion correction rigid
    mc = MotionCorrect(fnames, dview=dview, **opts.get_group('motion'))
    mc.motion_correct(save_movie=True)
    fname_mc = mc.fname_tot_els if pw_rigid else mc.fname_tot_rig
    if pw_rigid:
        bord_px = np.ceil(np.maximum(np.max(np.abs(mc.x_shifts_els)),
                                     np.max(np.abs(mc.y_shifts_els)))).astype(np.int)
    else:
        bord_px = np.ceil(np.max(np.abs(mc.shifts_rig))).astype(np.int)
        plt.subplot(1, 2, 1); plt.imshow(mc.total_template_rig)  # % plot template
        plt.subplot(1, 2, 2); plt.plot(mc.shifts_rig)  # % plot rigid shifts
        plt.legend(['x shifts', 'y shifts'])
        plt.xlabel('frames')
        plt.ylabel('pixels')

    bord_px = 0 if border_nan is 'copy' else bord_px
    fname_new = cm.save_memmap(fname_mc, base_name='memmap_', order='C',
                               border_to_0=bord_px)
else:  # if no motion correction just memory map the file
    fname_new = cm.save_memmap(fnames, base_name='memmap_',
                               order='C', border_to_0=0, dview=dview)
# Out:
#       254751 [motion_correction.py:motion_correct_rigid():258] [1204] Entering Rigid Motion Correction
#       254753 [motion_correction.py:motion_correct_rigid():259] [1204] 1.3795735
#       255047 [movies.py:      extract_shifts():256] [1204] min_val in extract_shifts: -0.297609384059906
# /Users/johnmarshall/miniconda3/envs/caiman/lib/python3.6/site-packages/caiman/base/movies.py:258: UserWarning: ** Pixel averages are too negative. Removing 1 percentile. **
#   '** Pixel averages are too negative. Removing 1 percentile. **')
# /Users/johnmarshall/miniconda3/envs/caiman/lib/python3.6/site-packages/caiman/base/movies.py:277: UserWarning: Pixel averages are too negative for template. Removing 1 percentile.
#   'Pixel averages are too negative for template. Removing 1 percentile.')
#       255290 [movies.py:        apply_shifts():352] [1204] cubic interpolation
#       255586 [movies.py:      extract_shifts():256] [1204] min_val in extract_shifts: -0.297609384059906
#       255834 [movies.py:        apply_shifts():352] [1204] cubic interpolation
#       256118 [movies.py:      extract_shifts():256] [1204] min_val in extract_shifts: -0.297609384059906
#       256382 [movies.py:        apply_shifts():352] [1204] cubic interpolation
#       256617 [motion_correction.py:motion_correct_batch_rigid():2229] [1204] Adding to movie 1.3795735
#       256618 [motion_correction.py:motion_correct_batch_rigid():2235] [1204] 0
#       256620 [motion_correction.py:motion_correct_batch_rigid():2239] [1204] saving!
#       258545 [motion_correction.py:motion_correction_piecewise():2564] [1204] ** Starting parallel motion correction **
#       272152 [motion_correction.py:motion_correction_piecewise():2572] [1204] ** Finished parallel motion correction **
#       272243 [motion_correction.py:motion_correct_batch_rigid():2252] [1204] 0.2130695
#       273360 [mmapping.py:         save_memmap():398] [1204] /Volumes/My_Passport/MiniscopeMovies/caiman_pipeline_test/H10_M19_S59msCam9_substack_rig__d1_480_d2_752_d3_1_order_F_frames_101_.mmap
#       273363 [movies.py:                load():1352] [1204] loading in memory
#       273634 [movies.py:                load():1355] [1204] mmap
#       273862 [mmapping.py:         save_memmap():462] [1204] SAVING WITH numpy.tofile()
#       275720 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       275747 [font_manager.py:    _findfont_cached():1254] [1204] findfont: Matching :family=sans-serif:style=normal:variant=normal:weight=normal:stretch=normal:size=10.0 to DejaVu Sans ('/Users/johnmarshall/miniconda3/envs/caiman/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf') with score of 0.050000.
#       275785 [_base.py:_update_title_position():2515] [1204] update_title_pos

# %%
# load memory mappable file
Yr, dims, T = cm.load_memmap(fname_new)
images = Yr.T.reshape((T,) + dims, order='F')

# %%
# parameters for source extraction and deconvolution
p = 1               # order of the autoregressive system
K = None            # upper bound on number of components per patch, in general None
gSig = (3, 3)       # gaussian width of a 2D gaussian kernel, which approximates a neuron
gSiz = (13, 13)     # average diameter of a neuron, in general 4*gSig+1
Ain = None          # possibility to seed with predetermined binary masks
merge_thresh = .7   # merging threshold, max correlation allowed
rf = 40             # half-size of the patches in pixels. e.g., if rf=40, patches are 80x80
stride_cnmf = 20    # amount of overlap between the patches in pixels
#                     (keep it at least large as gSiz, i.e 4 times the neuron size gSig)
tsub = 2            # downsampling factor in time for initialization,
#                     increase if you have memory problems
ssub = 1            # downsampling factor in space for initialization,
#                     increase if you have memory problems
#                     you can pass them here as boolean vectors
low_rank_background = None  # None leaves background of each patch intact,
#                     True performs global low-rank approximation if gnb>0
gnb = 0             # number of background components (rank) if positive,
#                     else exact ring model with following settings
#                         gnb= 0: Return background as b and W
#                         gnb=-1: Return full rank background B
#                         gnb<-1: Don't return background
nb_patch = 0        # number of background components (rank) per patch if gnb>0,
#                     else it is set automatically
min_corr = .8       # min peak value from correlation image
min_pnr = 10        # min peak to noise ration from PNR image
ssub_B = 2          # additional downsampling factor in space for background
ring_size_factor = 1.4  # radius of ring is gSiz*ring_size_factor

opts.change_params(params_dict={'method_init': 'corr_pnr',  # use this for 1 photon
                                'K': K,
                                'gSig': gSig,
                                'gSiz': gSiz,
                                'merge_thresh': merge_thresh,
                                'p': p,
                                'tsub': tsub,
                                'ssub': ssub,
                                'rf': rf,
                                'stride': stride_cnmf,
                                'only_init': True,    # set it to True to run CNMF-E
                                'nb': gnb,
                                'nb_patch': nb_patch,
                                'method_deconvolution': 'oasis',       # could use 'cvxpy' alternatively
                                'low_rank_background': low_rank_background,
                                'update_background_components': True,  # sometimes setting to False improve the results
                                'min_corr': min_corr,
                                'min_pnr': min_pnr,
                                'normalize_init': False,               # just leave as is
                                'center_psf': True,                    # leave as is for 1 photon
                                'ssub_B': ssub_B,
                                'ring_size_factor': ring_size_factor,
                                'del_duplicates': True,                # whether to remove duplicates from initialization
                                'border_pix': bord_px})                # number of pixels to not consider in the borders)
# Out:
#       533389 [params.py:                 set():780] [1204] Changing key rf in group patch from None to 40
#       533391 [params.py:                 set():780] [1204] Changing key stride in group patch from None to 20
#       533392 [params.py:                 set():780] [1204] Changing key nb_patch in group patch from 1 to 0
#       533393 [params.py:                 set():780] [1204] Changing key low_rank_background in group patch from True to None
#       533397 [params.py:                 set():780] [1204] Changing key del_duplicates in group patch from False to True
#       533400 [params.py:                 set():780] [1204] Changing key p in group preprocess from 2 to 1
#       533402 [params.py:                 set():780] [1204] Changing key method_init in group init from greedy_roi to corr_pnr
#       533403 [params.py:                 set():780] [1204] Changing key K in group init from 30 to None
#       533404 [params.py:                 set():780] [1204] Changing key gSig in group init from [5, 5] to (3, 3)
#       533406 [params.py:                 set():780] [1204] Changing key gSiz in group init from [11, 11] to (13, 13)
#       533406 [params.py:                 set():780] [1204] Changing key ssub in group init from 2 to 1
#       533407 [params.py:                 set():780] [1204] Changing key nb in group init from 1 to 0
#       533409 [params.py:                 set():780] [1204] Changing key min_corr in group init from 0.85 to 0.8
#       533410 [params.py:                 set():780] [1204] Changing key min_pnr in group init from 20 to 10
#       533411 [params.py:                 set():780] [1204] Changing key normalize_init in group init from True to False
#       533412 [params.py:                 set():780] [1204] Changing key center_psf in group init from False to True
#       533414 [params.py:                 set():780] [1204] Changing key ring_size_factor in group init from 1.5 to 1.4
#       533419 [params.py:                 set():780] [1204] Changing key nb in group spatial from 1 to 0
#       533420 [params.py:                 set():780] [1204] Changing key p in group temporal from 2 to 1
#       533422 [params.py:                 set():780] [1204] Changing key nb in group temporal from 1 to 0

# %%
# compute some summary images (correlation and peak to noise)
cn_filter, pnr = cm.summary_images.correlation_pnr(images, gSig=gSig[0], swap_dim=False) # change swap dim if output looks weird, it is a problem with tiffile
# inspect the summary images and set the parameters
inspect_correlation_pnr(cn_filter, pnr)
# Out:
#       585439 [colorbar.py:_get_ticker_locator_formatter():507] [1204] locator: <matplotlib.colorbar._ColorbarAutoLocator object at 0x1121ef978>
#       585441 [colorbar.py:        update_ticks():536] [1204] Using auto colorbar locator on colorbar
#       585441 [colorbar.py:        update_ticks():537] [1204] locator: <matplotlib.colorbar._ColorbarAutoLocator object at 0x1121ef978>
#       585442 [colorbar.py:         _add_solids():693] [1204] Setting pcolormesh
#       585487 [colorbar.py:_get_ticker_locator_formatter():507] [1204] locator: <matplotlib.colorbar._ColorbarAutoLocator object at 0x112274048>
#       585487 [colorbar.py:        update_ticks():536] [1204] Using auto colorbar locator on colorbar
#       585488 [colorbar.py:        update_ticks():537] [1204] locator: <matplotlib.colorbar._ColorbarAutoLocator object at 0x112274048>
#       585489 [colorbar.py:         _add_solids():693] [1204] Setting pcolormesh
#       585583 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       585623 [font_manager.py:    _findfont_cached():1254] [1204] findfont: Matching :family=sans-serif:style=normal:variant=normal:weight=normal:stretch=normal:size=12.0 to DejaVu Sans ('/Users/johnmarshall/miniconda3/envs/caiman/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf') with score of 0.050000.
#       585626 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       585647 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       585682 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       585700 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       585707 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       585714 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       585720 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       587620 [colorbar.py:_get_ticker_locator_formatter():507] [1204] locator: <matplotlib.colorbar._ColorbarAutoLocator object at 0x1121ef8d0>
#       587621 [colorbar.py:        update_ticks():536] [1204] Using auto colorbar locator on colorbar
#       587622 [colorbar.py:        update_ticks():537] [1204] locator: <matplotlib.colorbar._ColorbarAutoLocator object at 0x1121ef8d0>
#       587623 [colorbar.py:         _add_solids():693] [1204] Setting pcolormesh
#       587632 [colorbar.py:_get_ticker_locator_formatter():507] [1204] locator: <matplotlib.colorbar._ColorbarAutoLocator object at 0x112269ef0>
#       587633 [colorbar.py:        update_ticks():536] [1204] Using auto colorbar locator on colorbar
#       587634 [colorbar.py:        update_ticks():537] [1204] locator: <matplotlib.colorbar._ColorbarAutoLocator object at 0x112269ef0>
#       587634 [colorbar.py:         _add_solids():693] [1204] Setting pcolormesh
#       587639 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       587665 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       587680 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       587701 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       587712 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       587717 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       587723 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       587728 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       588194 [colorbar.py:_get_ticker_locator_formatter():507] [1204] locator: <matplotlib.colorbar._ColorbarAutoLocator object at 0x124f5f9b0>
#       588195 [colorbar.py:        update_ticks():536] [1204] Using auto colorbar locator on colorbar
#       588196 [colorbar.py:        update_ticks():537] [1204] locator: <matplotlib.colorbar._ColorbarAutoLocator object at 0x124f5f9b0>
#       588196 [colorbar.py:         _add_solids():693] [1204] Setting pcolormesh
#       588206 [colorbar.py:_get_ticker_locator_formatter():507] [1204] locator: <matplotlib.colorbar._ColorbarAutoLocator object at 0x125885710>
#       588207 [colorbar.py:        update_ticks():536] [1204] Using auto colorbar locator on colorbar
#       588208 [colorbar.py:        update_ticks():537] [1204] locator: <matplotlib.colorbar._ColorbarAutoLocator object at 0x125885710>
#       588208 [colorbar.py:         _add_solids():693] [1204] Setting pcolormesh
#       588214 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       588241 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       588253 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       588275 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       588285 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       588290 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       588296 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       588301 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       588690 [colorbar.py:_get_ticker_locator_formatter():507] [1204] locator: <matplotlib.colorbar._ColorbarAutoLocator object at 0x125885c88>
#       588691 [colorbar.py:        update_ticks():536] [1204] Using auto colorbar locator on colorbar
#       588692 [colorbar.py:        update_ticks():537] [1204] locator: <matplotlib.colorbar._ColorbarAutoLocator object at 0x125885c88>
#       588692 [colorbar.py:         _add_solids():693] [1204] Setting pcolormesh
#       588701 [colorbar.py:_get_ticker_locator_formatter():507] [1204] locator: <matplotlib.colorbar._ColorbarAutoLocator object at 0x125885c50>
#       588702 [colorbar.py:        update_ticks():536] [1204] Using auto colorbar locator on colorbar
#       588703 [colorbar.py:        update_ticks():537] [1204] locator: <matplotlib.colorbar._ColorbarAutoLocator object at 0x125885c50>
#       588704 [colorbar.py:         _add_solids():693] [1204] Setting pcolormesh
#       588709 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       588738 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       588758 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       588781 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       588791 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       588797 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       588802 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       588807 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       589618 [colorbar.py:_get_ticker_locator_formatter():507] [1204] locator: <matplotlib.colorbar._ColorbarAutoLocator object at 0x1121ef9b0>
#       589619 [colorbar.py:        update_ticks():536] [1204] Using auto colorbar locator on colorbar
#       589620 [colorbar.py:        update_ticks():537] [1204] locator: <matplotlib.colorbar._ColorbarAutoLocator object at 0x1121ef9b0>
#       589621 [colorbar.py:         _add_solids():693] [1204] Setting pcolormesh
#       589630 [colorbar.py:_get_ticker_locator_formatter():507] [1204] locator: <matplotlib.colorbar._ColorbarAutoLocator object at 0x124f58080>
#       589631 [colorbar.py:        update_ticks():536] [1204] Using auto colorbar locator on colorbar
#       589631 [colorbar.py:        update_ticks():537] [1204] locator: <matplotlib.colorbar._ColorbarAutoLocator object at 0x124f58080>
#       589632 [colorbar.py:         _add_solids():693] [1204] Setting pcolormesh
#       589637 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       589666 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       589684 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       589706 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       589717 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       589722 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       589728 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       589734 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       590362 [colorbar.py:_get_ticker_locator_formatter():507] [1204] locator: <matplotlib.colorbar._ColorbarAutoLocator object at 0x123bc1518>
#       590363 [colorbar.py:        update_ticks():536] [1204] Using auto colorbar locator on colorbar
#       590364 [colorbar.py:        update_ticks():537] [1204] locator: <matplotlib.colorbar._ColorbarAutoLocator object at 0x123bc1518>
#       590365 [colorbar.py:         _add_solids():693] [1204] Setting pcolormesh
#       590374 [colorbar.py:_get_ticker_locator_formatter():507] [1204] locator: <matplotlib.colorbar._ColorbarAutoLocator object at 0x124f58358>
#       590375 [colorbar.py:        update_ticks():536] [1204] Using auto colorbar locator on colorbar
#       590376 [colorbar.py:        update_ticks():537] [1204] locator: <matplotlib.colorbar._ColorbarAutoLocator object at 0x124f58358>
#       590376 [colorbar.py:         _add_solids():693] [1204] Setting pcolormesh
#       590381 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       590408 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       590424 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       590447 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       590457 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       590463 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       590470 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       590476 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       591226 [colorbar.py:_get_ticker_locator_formatter():507] [1204] locator: <matplotlib.colorbar._ColorbarAutoLocator object at 0x124f5f668>
#       591227 [colorbar.py:        update_ticks():536] [1204] Using auto colorbar locator on colorbar
#       591228 [colorbar.py:        update_ticks():537] [1204] locator: <matplotlib.colorbar._ColorbarAutoLocator object at 0x124f5f668>
#       591229 [colorbar.py:         _add_solids():693] [1204] Setting pcolormesh
#       591237 [colorbar.py:_get_ticker_locator_formatter():507] [1204] locator: <matplotlib.colorbar._ColorbarAutoLocator object at 0x112274400>
#       591238 [colorbar.py:        update_ticks():536] [1204] Using auto colorbar locator on colorbar
#       591239 [colorbar.py:        update_ticks():537] [1204] locator: <matplotlib.colorbar._ColorbarAutoLocator object at 0x112274400>
#       591240 [colorbar.py:         _add_solids():693] [1204] Setting pcolormesh
#       591244 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       591273 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       591288 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       591310 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       591322 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       591327 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       591332 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       591338 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       593322 [colorbar.py:_get_ticker_locator_formatter():507] [1204] locator: <matplotlib.colorbar._ColorbarAutoLocator object at 0x123ba3eb8>
#       593323 [colorbar.py:        update_ticks():536] [1204] Using auto colorbar locator on colorbar
#       593324 [colorbar.py:        update_ticks():537] [1204] locator: <matplotlib.colorbar._ColorbarAutoLocator object at 0x123ba3eb8>
#       593325 [colorbar.py:         _add_solids():693] [1204] Setting pcolormesh
#       593333 [colorbar.py:_get_ticker_locator_formatter():507] [1204] locator: <matplotlib.colorbar._ColorbarAutoLocator object at 0x112274240>
#       593334 [colorbar.py:        update_ticks():536] [1204] Using auto colorbar locator on colorbar
#       593335 [colorbar.py:        update_ticks():537] [1204] locator: <matplotlib.colorbar._ColorbarAutoLocator object at 0x112274240>
#       593335 [colorbar.py:         _add_solids():693] [1204] Setting pcolormesh
#       593340 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       593367 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       593382 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       593405 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       593416 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       593421 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       593427 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       593432 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       594019 [colorbar.py:_get_ticker_locator_formatter():507] [1204] locator: <matplotlib.colorbar._ColorbarAutoLocator object at 0x123bc1cc0>
#       594020 [colorbar.py:        update_ticks():536] [1204] Using auto colorbar locator on colorbar
#       594021 [colorbar.py:        update_ticks():537] [1204] locator: <matplotlib.colorbar._ColorbarAutoLocator object at 0x123bc1cc0>
#       594022 [colorbar.py:         _add_solids():693] [1204] Setting pcolormesh
#       594031 [colorbar.py:_get_ticker_locator_formatter():507] [1204] locator: <matplotlib.colorbar._ColorbarAutoLocator object at 0x123bc14e0>
#       594032 [colorbar.py:        update_ticks():536] [1204] Using auto colorbar locator on colorbar
#       594033 [colorbar.py:        update_ticks():537] [1204] locator: <matplotlib.colorbar._ColorbarAutoLocator object at 0x123bc14e0>
#       594033 [colorbar.py:         _add_solids():693] [1204] Setting pcolormesh
#       594039 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       594062 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       594082 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       594108 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       594119 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       594124 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       594130 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       594135 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       594602 [colorbar.py:_get_ticker_locator_formatter():507] [1204] locator: <matplotlib.colorbar._ColorbarAutoLocator object at 0x1121efa58>
#       594603 [colorbar.py:        update_ticks():536] [1204] Using auto colorbar locator on colorbar
#       594604 [colorbar.py:        update_ticks():537] [1204] locator: <matplotlib.colorbar._ColorbarAutoLocator object at 0x1121efa58>
#       594605 [colorbar.py:         _add_solids():693] [1204] Setting pcolormesh
#       594614 [colorbar.py:_get_ticker_locator_formatter():507] [1204] locator: <matplotlib.colorbar._ColorbarAutoLocator object at 0x123ba37f0>
#       594615 [colorbar.py:        update_ticks():536] [1204] Using auto colorbar locator on colorbar
#       594616 [colorbar.py:        update_ticks():537] [1204] locator: <matplotlib.colorbar._ColorbarAutoLocator object at 0x123ba37f0>
#       594616 [colorbar.py:         _add_solids():693] [1204] Setting pcolormesh
#       594621 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       594649 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       594665 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       594686 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       594697 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       594702 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       594709 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       594713 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       595260 [colorbar.py:_get_ticker_locator_formatter():507] [1204] locator: <matplotlib.colorbar._ColorbarAutoLocator object at 0x123b9b940>
#       595261 [colorbar.py:        update_ticks():536] [1204] Using auto colorbar locator on colorbar
#       595262 [colorbar.py:        update_ticks():537] [1204] locator: <matplotlib.colorbar._ColorbarAutoLocator object at 0x123b9b940>
#       595263 [colorbar.py:         _add_solids():693] [1204] Setting pcolormesh
#       595271 [colorbar.py:_get_ticker_locator_formatter():507] [1204] locator: <matplotlib.colorbar._ColorbarAutoLocator object at 0x123ba3198>
#       595272 [colorbar.py:        update_ticks():536] [1204] Using auto colorbar locator on colorbar
#       595273 [colorbar.py:        update_ticks():537] [1204] locator: <matplotlib.colorbar._ColorbarAutoLocator object at 0x123ba3198>
#       595273 [colorbar.py:         _add_solids():693] [1204] Setting pcolormesh
#       595279 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       595306 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       595321 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       595343 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       595354 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       595359 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       595365 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       595370 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       596148 [colorbar.py:_get_ticker_locator_formatter():507] [1204] locator: <matplotlib.colorbar._ColorbarAutoLocator object at 0x123bc1588>
#       596149 [colorbar.py:        update_ticks():536] [1204] Using auto colorbar locator on colorbar
#       596150 [colorbar.py:        update_ticks():537] [1204] locator: <matplotlib.colorbar._ColorbarAutoLocator object at 0x123bc1588>
#       596151 [colorbar.py:         _add_solids():693] [1204] Setting pcolormesh
#       596160 [colorbar.py:_get_ticker_locator_formatter():507] [1204] locator: <matplotlib.colorbar._ColorbarAutoLocator object at 0x123ba3860>
#       596161 [colorbar.py:        update_ticks():536] [1204] Using auto colorbar locator on colorbar
#       596162 [colorbar.py:        update_ticks():537] [1204] locator: <matplotlib.colorbar._ColorbarAutoLocator object at 0x123ba3860>
#       596163 [colorbar.py:         _add_solids():693] [1204] Setting pcolormesh
#       596168 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       596194 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       596209 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       596232 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       596244 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       596251 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       596258 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       596264 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       596604 [colorbar.py:_get_ticker_locator_formatter():507] [1204] locator: <matplotlib.colorbar._ColorbarAutoLocator object at 0x123b4df98>
#       596605 [colorbar.py:        update_ticks():536] [1204] Using auto colorbar locator on colorbar
#       596606 [colorbar.py:        update_ticks():537] [1204] locator: <matplotlib.colorbar._ColorbarAutoLocator object at 0x123b4df98>
#       596607 [colorbar.py:         _add_solids():693] [1204] Setting pcolormesh
#       596616 [colorbar.py:_get_ticker_locator_formatter():507] [1204] locator: <matplotlib.colorbar._ColorbarAutoLocator object at 0x123c1d3c8>
#       596617 [colorbar.py:        update_ticks():536] [1204] Using auto colorbar locator on colorbar
#       596618 [colorbar.py:        update_ticks():537] [1204] locator: <matplotlib.colorbar._ColorbarAutoLocator object at 0x123c1d3c8>
#       596619 [colorbar.py:         _add_solids():693] [1204] Setting pcolormesh
#       596623 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       596648 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       596663 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       596685 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       596695 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       596700 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       596706 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       596712 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       597492 [colorbar.py:_get_ticker_locator_formatter():507] [1204] locator: <matplotlib.colorbar._ColorbarAutoLocator object at 0x123b4d240>
#       597493 [colorbar.py:        update_ticks():536] [1204] Using auto colorbar locator on colorbar
#       597494 [colorbar.py:        update_ticks():537] [1204] locator: <matplotlib.colorbar._ColorbarAutoLocator object at 0x123b4d240>
#       597494 [colorbar.py:         _add_solids():693] [1204] Setting pcolormesh
#       597503 [colorbar.py:_get_ticker_locator_formatter():507] [1204] locator: <matplotlib.colorbar._ColorbarAutoLocator object at 0x124f5f208>
#       597504 [colorbar.py:        update_ticks():536] [1204] Using auto colorbar locator on colorbar
#       597505 [colorbar.py:        update_ticks():537] [1204] locator: <matplotlib.colorbar._ColorbarAutoLocator object at 0x124f5f208>
#       597506 [colorbar.py:         _add_solids():693] [1204] Setting pcolormesh
#       597511 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       597537 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       597551 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       597572 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       597583 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       597588 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       597594 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       597599 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       598886 [colorbar.py:_get_ticker_locator_formatter():507] [1204] locator: <matplotlib.colorbar._ColorbarAutoLocator object at 0x123bc1f98>
#       598887 [colorbar.py:        update_ticks():536] [1204] Using auto colorbar locator on colorbar
#       598888 [colorbar.py:        update_ticks():537] [1204] locator: <matplotlib.colorbar._ColorbarAutoLocator object at 0x123bc1f98>
#       598889 [colorbar.py:         _add_solids():693] [1204] Setting pcolormesh
#       598898 [colorbar.py:_get_ticker_locator_formatter():507] [1204] locator: <matplotlib.colorbar._ColorbarAutoLocator object at 0x124f5f748>
#       598898 [colorbar.py:        update_ticks():536] [1204] Using auto colorbar locator on colorbar
#       598899 [colorbar.py:        update_ticks():537] [1204] locator: <matplotlib.colorbar._ColorbarAutoLocator object at 0x124f5f748>
#       598900 [colorbar.py:         _add_solids():693] [1204] Setting pcolormesh
#       598904 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       598931 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       598945 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       598969 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       598988 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       598993 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       598998 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       599005 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       599574 [colorbar.py:_get_ticker_locator_formatter():507] [1204] locator: <matplotlib.colorbar._ColorbarAutoLocator object at 0x1121d20b8>
#       599575 [colorbar.py:        update_ticks():536] [1204] Using auto colorbar locator on colorbar
#       599576 [colorbar.py:        update_ticks():537] [1204] locator: <matplotlib.colorbar._ColorbarAutoLocator object at 0x1121d20b8>
#       599577 [colorbar.py:         _add_solids():693] [1204] Setting pcolormesh
#       599586 [colorbar.py:_get_ticker_locator_formatter():507] [1204] locator: <matplotlib.colorbar._ColorbarAutoLocator object at 0x124f5f4e0>
#       599587 [colorbar.py:        update_ticks():536] [1204] Using auto colorbar locator on colorbar
#       599588 [colorbar.py:        update_ticks():537] [1204] locator: <matplotlib.colorbar._ColorbarAutoLocator object at 0x124f5f4e0>
#       599589 [colorbar.py:         _add_solids():693] [1204] Setting pcolormesh
#       599593 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       599619 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       599631 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       599654 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       599667 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       599672 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       599677 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       599682 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       600832 [colorbar.py:_get_ticker_locator_formatter():507] [1204] locator: <matplotlib.colorbar._ColorbarAutoLocator object at 0x123b4def0>
#       600834 [colorbar.py:        update_ticks():536] [1204] Using auto colorbar locator on colorbar
#       600835 [colorbar.py:        update_ticks():537] [1204] locator: <matplotlib.colorbar._ColorbarAutoLocator object at 0x123b4def0>
#       600836 [colorbar.py:         _add_solids():693] [1204] Setting pcolormesh
#       600845 [colorbar.py:_get_ticker_locator_formatter():507] [1204] locator: <matplotlib.colorbar._ColorbarAutoLocator object at 0x124f5f390>
#       600846 [colorbar.py:        update_ticks():536] [1204] Using auto colorbar locator on colorbar
#       600846 [colorbar.py:        update_ticks():537] [1204] locator: <matplotlib.colorbar._ColorbarAutoLocator object at 0x124f5f390>
#       600847 [colorbar.py:         _add_solids():693] [1204] Setting pcolormesh
#       600852 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       600879 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       600892 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       600913 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       600924 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       600929 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       600935 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       600941 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       602120 [colorbar.py:_get_ticker_locator_formatter():507] [1204] locator: <matplotlib.colorbar._ColorbarAutoLocator object at 0x124f43898>
#       602121 [colorbar.py:        update_ticks():536] [1204] Using auto colorbar locator on colorbar
#       602122 [colorbar.py:        update_ticks():537] [1204] locator: <matplotlib.colorbar._ColorbarAutoLocator object at 0x124f43898>
#       602123 [colorbar.py:         _add_solids():693] [1204] Setting pcolormesh
#       602132 [colorbar.py:_get_ticker_locator_formatter():507] [1204] locator: <matplotlib.colorbar._ColorbarAutoLocator object at 0x123bd1208>
#       602132 [colorbar.py:        update_ticks():536] [1204] Using auto colorbar locator on colorbar
#       602133 [colorbar.py:        update_ticks():537] [1204] locator: <matplotlib.colorbar._ColorbarAutoLocator object at 0x123bd1208>
#       602134 [colorbar.py:         _add_solids():693] [1204] Setting pcolormesh
#       602138 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       602164 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       602177 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       602199 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       602209 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       602215 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       602220 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       602225 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       603722 [colorbar.py:_get_ticker_locator_formatter():507] [1204] locator: <matplotlib.colorbar._ColorbarAutoLocator object at 0x123b63198>
#       603723 [colorbar.py:        update_ticks():536] [1204] Using auto colorbar locator on colorbar
#       603724 [colorbar.py:        update_ticks():537] [1204] locator: <matplotlib.colorbar._ColorbarAutoLocator object at 0x123b63198>
#       603724 [colorbar.py:         _add_solids():693] [1204] Setting pcolormesh
#       603733 [colorbar.py:_get_ticker_locator_formatter():507] [1204] locator: <matplotlib.colorbar._ColorbarAutoLocator object at 0x123ba3b00>
#       603734 [colorbar.py:        update_ticks():536] [1204] Using auto colorbar locator on colorbar
#       603735 [colorbar.py:        update_ticks():537] [1204] locator: <matplotlib.colorbar._ColorbarAutoLocator object at 0x123ba3b00>
#       603736 [colorbar.py:         _add_solids():693] [1204] Setting pcolormesh
#       603741 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       603765 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       603779 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       603803 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       603815 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       603820 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       603825 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       603830 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       605404 [colorbar.py:_get_ticker_locator_formatter():507] [1204] locator: <matplotlib.colorbar._ColorbarAutoLocator object at 0x123bc11d0>
#       605405 [colorbar.py:        update_ticks():536] [1204] Using auto colorbar locator on colorbar
#       605406 [colorbar.py:        update_ticks():537] [1204] locator: <matplotlib.colorbar._ColorbarAutoLocator object at 0x123bc11d0>
#       605407 [colorbar.py:         _add_solids():693] [1204] Setting pcolormesh
#       605416 [colorbar.py:_get_ticker_locator_formatter():507] [1204] locator: <matplotlib.colorbar._ColorbarAutoLocator object at 0x125885c50>
#       605416 [colorbar.py:        update_ticks():536] [1204] Using auto colorbar locator on colorbar
#       605417 [colorbar.py:        update_ticks():537] [1204] locator: <matplotlib.colorbar._ColorbarAutoLocator object at 0x125885c50>
#       605418 [colorbar.py:         _add_solids():693] [1204] Setting pcolormesh
#       605424 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       605451 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       605465 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       605487 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       605498 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       605504 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       605509 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       605514 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       606228 [colorbar.py:_get_ticker_locator_formatter():507] [1204] locator: <matplotlib.colorbar._ColorbarAutoLocator object at 0x124f514e0>
#       606229 [colorbar.py:        update_ticks():536] [1204] Using auto colorbar locator on colorbar
#       606230 [colorbar.py:        update_ticks():537] [1204] locator: <matplotlib.colorbar._ColorbarAutoLocator object at 0x124f514e0>
#       606231 [colorbar.py:         _add_solids():693] [1204] Setting pcolormesh
#       606240 [colorbar.py:_get_ticker_locator_formatter():507] [1204] locator: <matplotlib.colorbar._ColorbarAutoLocator object at 0x123c25400>
#       606241 [colorbar.py:        update_ticks():536] [1204] Using auto colorbar locator on colorbar
#       606242 [colorbar.py:        update_ticks():537] [1204] locator: <matplotlib.colorbar._ColorbarAutoLocator object at 0x123c25400>
#       606243 [colorbar.py:         _add_solids():693] [1204] Setting pcolormesh
#       606247 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       606275 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       606293 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       606317 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       606328 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       606333 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       606338 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       606344 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       606910 [colorbar.py:_get_ticker_locator_formatter():507] [1204] locator: <matplotlib.colorbar._ColorbarAutoLocator object at 0x1121d2438>
#       606911 [colorbar.py:        update_ticks():536] [1204] Using auto colorbar locator on colorbar
#       606912 [colorbar.py:        update_ticks():537] [1204] locator: <matplotlib.colorbar._ColorbarAutoLocator object at 0x1121d2438>
#       606912 [colorbar.py:         _add_solids():693] [1204] Setting pcolormesh
#       606922 [colorbar.py:_get_ticker_locator_formatter():507] [1204] locator: <matplotlib.colorbar._ColorbarAutoLocator object at 0x124f43c88>
#       606923 [colorbar.py:        update_ticks():536] [1204] Using auto colorbar locator on colorbar
#       606923 [colorbar.py:        update_ticks():537] [1204] locator: <matplotlib.colorbar._ColorbarAutoLocator object at 0x124f43c88>
#       606924 [colorbar.py:         _add_solids():693] [1204] Setting pcolormesh
#       606930 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       606956 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       606970 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       606992 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       607002 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       607008 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       607013 [_base.py:_update_title_position():2515] [1204] update_title_pos
#       607018 [_base.py:_update_title_position():2515] [1204] update_title_pos

# %%
# print parameters set above, modify them if necessary based on summary images
print(min_corr) # min correlation of peak (from correlation image)
print(min_pnr)  # min peak to noise ratio
# Out:
# 0.8
# 10

# %%
cnm = cnmf.CNMF(n_processes=n_processes, dview=dview, Ain=Ain, params=opts)

# %%
cnm.fit(images)

# %%
cnm.save('/Volumes/My_Passport/MiniscopeMovies/caiman_pipeline_test/cmn_output.hdf5)
